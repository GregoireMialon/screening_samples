# %% [markdown]
# # PLOT RESULTS

# %%
import os
import numpy as np
import re
from tools import plot_experiment

# %%
exp = 'synthetic'

# %%
def show_results(conds, zoom):
    exists=False
    for file in os.listdir('results/' + exp):
        filename = os.fsdecode(file)
        if all(cond in filename for cond in conds):
            print(filename)
            data = np.load('results/' + exp + '/' + filename)
            plot_experiment(data=data, zoom=zoom)
            exists=True
    if not exists:
        print('Sorry, the combination you asked is not in the results.')
    return

# %%
conds = ['X_size_100', 'loss_truncated_squared']
zoom = (0, 1)
show_results(conds, zoom)
# Out:
# X_size_100_sub_ell_0_loss_truncated_squared_lmbda_0.01_n_ellipsoid_100_intercept_False_mu_10_redundant_0_noise_0.1_better_init_0_better_radius_0_cut_ell_False_clip_ell_False.npy
# X_size_100_sub_ell_0_loss_truncated_squared_lmbda_0.01_n_ellipsoid_100_intercept_False_mu_1.0_redundant_0_noise_0.1_better_init_0_better_radius_0_cut_ell_False_clip_ell_False.npy
